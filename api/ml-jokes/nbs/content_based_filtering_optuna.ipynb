# %% [markdown]
# Authors:
#     <br>Alejandro Alvarez (axa)
#     <br>Brenda Palma (bpalmagu)
#
# # <center>ML-Jokes: Content-Based Filtering</center>

# %%
# Path to ml-jokes folder
import os
if os.getcwd().split('/')[-2] == 'ml-jokes': os.chdir('..')
print(f'Current directory: {os.getcwd()}')
assert set(['data', 'mljokes', 'environment.yml', 'nbs']) <= set(os.listdir()), \
    'Wrong path; go to ./heinz-95729-project/api/ml-jokes'
# Out:
# Current directory: /home/alejandroxag/my_files/heinz-95729-project/api/ml-jokes

# %%
# imports
import time
import tqdm
import pickle
import numpy as np
import pandas as pd
from mljokes.topics import get_lda_topics
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
from mljokes.data import read_jokes, read_ratings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import HistGradientBoostingRegressor

# %% [markdown]
# # Regression model inputs

# %%
def get_reg_model_inputs(n_topics=5, random_state=0):

    # Load jokes and ratings
    jokes_df = read_jokes()
    ratings_df = read_ratings()

    # Topics
    topics = pd.DataFrame(get_lda_topics(text=jokes_df.clean_text, 
                                         n_topics=n_topics, 
                                         random_state=random_state)) \
               .reset_index().rename(columns={'index': 'joke_id'})
    topics.loc[:, 'joke_id'] = topics.joke_id + 1

    # User-joke information
    user_joke_info = ratings_df.copy()
    user_joke_info.reset_index(inplace=True)
    user_joke_info.rename(columns={'index': 'user_id'}, inplace=True)
    user_joke_info.drop(columns='count_rated', inplace=True)
    user_joke_info = pd.melt(user_joke_info, 
                                id_vars=['user_id'],
                                var_name='joke_id',
                                value_vars=user_joke_info.columns[1:],
                                value_name='rating')
    user_joke_info = user_joke_info.loc[user_joke_info.rating != 99.0]
    user_joke_info.sort_values(by=['user_id', 'joke_id'], inplace=True)
    user_joke_info = user_joke_info.merge(topics, how='left', on='joke_id')
    user_joke_info.rename(columns=dict(zip(user_joke_info.columns[3:],
                                    ['topic_percentage_' + c  for c in np.array(user_joke_info.columns[3:], dtype=str)])), 
                        inplace=True)
    user_joke_info.reset_index(drop=True, inplace=True)

    del jokes_df, ratings_df

    # User profiles
    user_profiles = user_joke_info.iloc[:, :2]
    user_profiles.loc[:, list(range(len(user_joke_info.columns[3:])))] = \
        (user_joke_info.rating / 10).values.reshape((-1, 1)) * user_joke_info.iloc[:, 3:].values

    user_profiles = user_profiles.groupby(['user_id'])[user_profiles.columns[2:]].agg('mean').reset_index()
    user_profiles.rename(columns=dict(zip(user_profiles.columns[1:],
                                    ['topic_user_rating_' + c for c in np.array(user_profiles.columns[1:], dtype=str)])), 
                        inplace=True)

    # User-joke inputs
    user_joke_inputs = user_joke_info.merge(user_profiles, how='left', on='user_id')

    user_joke_idxs = user_joke_inputs.loc[:, ['user_id', 'joke_id']]
    y = user_joke_inputs.rating.values
    X = user_joke_inputs.iloc[:, 3:].values

    del user_joke_info, user_profiles, user_joke_inputs

    return X, y, user_joke_idxs, topics

# %% [markdown]
# # Regression model (HGB)

# %% [markdown]
# ### Train-test split

# %%
# Data inputs
X, y, user_joke_idxs, topics = get_reg_model_inputs(n_topics=10)

# Data split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=True)
# Out:
# ./data/ratings/jester-data-3.xls
# ./data/ratings/jester-data-2.xls
# ./data/ratings/jester-data-1.xls

# %% [markdown]
# ### Optuna hypertuning

# %%
import optuna

def tune(objective, n_trials=10):
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=n_trials)

    params = study.best_params
    best_score = study.best_value
    print(f"Best score: {best_score}\n")
    print(f"Optimized parameters: {params}\n")
    return params


param_grid = {
              'learning_rate': [0.01, 0.1, 0.3],
              'max_depth': [5, 7, 13, None],
              'l2_regularization': [0.01, 0.01, 0.1, 1]
             }

def hgb_objective(trial):
    _learning_rate = trial.suggest_loguniform('learning_rate', low= )
    _n_estimators = trial.suggest_int("n_estimators", 50, 200)
    _max_depth = trial.suggest_int("max_depth", 5, 20)
    _min_samp_split = trial.suggest_int("min_samples_split", 2, 10)
    _min_samples_leaf = trial.suggest_int("min_samples_leaf", 2, 10)
    _max_features = trial.suggest_int("max_features", 10, 50)

    rf = RandomForestRegressor(
        max_depth=_max_depth,
        min_samples_split=_min_samp_split,
        min_samples_leaf=_min_samples_leaf,
        max_features=_max_features,
        n_estimators=_n_estimators,
        n_jobs=-1,
        random_state=RANDOM_SEED,
    )

    scores = cross_val_score(
        rf, X, y, cv=kfolds, scoring="neg_root_mean_squared_error"
    )
    return scores.mean()

# %%
subsample = np.random.randint(low=0, high=len(y_train), size=round(0.20 * len(y_train)))
X_gs, y_gs = X_train[subsample], y_train[subsample]

fixed_params = {
                'loss': 'absolute_error',
                'max_iter': 100_000,
                'early_stopping': True,
                'scoring': 'loss',
                'validation_fraction': 0.20,
                'tol': 1e-6,
                'n_iter_no_change': 20,
                'verbose': 4,
                'random_state': 0
               }

param_grid = {
              'learning_rate': [0.01, 0.1, 0.3],
              'max_depth': [5, 7, 13, None],
              'l2_regularization': [0.01, 0.01, 0.1, 1]
             }

hgb_gs = HistGradientBoostingRegressor().set_params(**fixed_params)

grid_search = GridSearchCV(hgb_gs, 
                           param_grid=param_grid, 
                           n_jobs=-1, 
                           refit=False, 
                           cv=[(slice(None), slice(None))],
                           verbose=4)

start_time = time.time()
grid_search.fit(X_gs, y_gs)
elapsed_time = time.time() - start_time
print(f'\nElapsed time: {elapsed_time:0.2f} seconds.\n')

with open('./results/hgb_26nov1100.pkl', 'wb') as f: 
  pickle.dump({'gs_object': grid_search, 'elapsed_time': elapsed_time}, f)
# Out:
# Fitting 1 folds for each of 48 candidates, totalling 48 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-ae978c7273ad> in <module>
#      30
#      31 start_time = time.time()
# ---> 32 grid_search.fit(X_gs, y_gs)
#      33 elapsed_time = time.time() - start_time
#      34 print(f'\nElapsed time: {elapsed_time:0.2f} seconds.\n')
#
# ~/miniconda3/envs/ecommerce_jokes/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# ~/miniconda3/envs/ecommerce_jokes/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# ~/miniconda3/envs/ecommerce_jokes/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# ~/miniconda3/envs/ecommerce_jokes/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~/miniconda3/envs/ecommerce_jokes/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~/miniconda3/envs/ecommerce_jokes/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/miniconda3/envs/ecommerce_jokes/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/miniconda3/envs/ecommerce_jokes/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Model fitting

# %%
# GS parameters loading
with open('./results/hgb_26nov1100.pkl', 'rb') as f: 
  grid_search = pickle.load(f)['gs_object']

# Train
hgb = HistGradientBoostingRegressor(**{**fixed_params, **grid_search.best_params_})
hgb.fit(X_train, y_train)

# Test
y_true = y_test
y_pred = hgb.predict(X_test)
print(f'MAE: {mean_absolute_error(y_true, y_pred)}')
predictions_df = pd.DataFrame({'y_true': y_true, 'y_pred': y_pred})
predictions_df.insert(2, 'error', np.abs(predictions_df.y_true - predictions_df.y_pred))
display(predictions_df)
# Out:
# Binning 0.212 GB of training data: 1.431 s
# Binning 0.053 GB of validation data: 0.354 s
# Fitting gradient boosted rounds:
# [1/100000] 1 tree, 31 leaves, max depth = 7, train loss: 4.28046, val loss: 4.27800, in 0.568s
# [2/100000] 1 tree, 31 leaves, max depth = 7, train loss: 4.16982, val loss: 4.16712, in 0.569s
# [3/100000] 1 tree, 31 leaves, max depth = 7, train loss: 4.07496, val loss: 4.07216, in 0.597s
# [4/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.99530, val loss: 3.99236, in 0.567s
# [5/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.92595, val loss: 3.92283, in 0.576s
# [6/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.86717, val loss: 3.86393, in 0.567s
# [7/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.81588, val loss: 3.81260, in 0.566s
# [8/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.76940, val loss: 3.76609, in 0.564s
# [9/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.72876, val loss: 3.72548, in 0.590s
# [10/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.69553, val loss: 3.69216, in 0.557s
# [11/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.66401, val loss: 3.66069, in 0.548s
# [12/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.63591, val loss: 3.63249, in 0.532s
# [13/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.61054, val loss: 3.60727, in 0.510s
# [14/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.58748, val loss: 3.58421, in 0.581s
# [15/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.56773, val loss: 3.56448, in 0.544s
# [16/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.54885, val loss: 3.54562, in 0.560s
# [17/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.53228, val loss: 3.52902, in 0.525s
# [18/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.51756, val loss: 3.51410, in 0.550s
# [19/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.50574, val loss: 3.50235, in 0.537s
# [20/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.49347, val loss: 3.49011, in 0.557s
# [21/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.48264, val loss: 3.47920, in 0.497s
# [22/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.47158, val loss: 3.46813, in 0.495s
# [23/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.46302, val loss: 3.45954, in 0.458s
# [24/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.45121, val loss: 3.44768, in 0.543s
# [25/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.44096, val loss: 3.43732, in 0.551s
# [26/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.43279, val loss: 3.42906, in 0.539s
# [27/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.42380, val loss: 3.42009, in 0.562s
# [28/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.41768, val loss: 3.41403, in 0.428s
# [29/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.41150, val loss: 3.40776, in 0.503s
# [30/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.40586, val loss: 3.40213, in 0.413s
# [31/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.39968, val loss: 3.39592, in 0.505s
# [32/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3
100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15465, val loss: 3.17740, in 0.151s
# [1325/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15464, val loss: 3.17740, in 0.173s
# [1326/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15463, val loss: 3.17740, in 0.176s
# [1327/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15462, val loss: 3.17739, in 0.179s
# [1328/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15461, val loss: 3.17739, in 0.237s
# [1329/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15460, val loss: 3.17739, in 0.144s
# [1330/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15460, val loss: 3.17739, in 0.166s
# [1331/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15459, val loss: 3.17738, in 0.164s
# [1332/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15458, val loss: 3.17738, in 0.158s
# [1333/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15457, val loss: 3.17738, in 0.157s
# [1334/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15456, val loss: 3.17738, in 0.138s
# [1335/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15456, val loss: 3.17737, in 0.140s
# [1336/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15455, val loss: 3.17737, in 0.167s
# [1337/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15454, val loss: 3.17737, in 0.165s
# [1338/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15453, val loss: 3.17737, in 0.184s
# [1339/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15452, val loss: 3.17737, in 0.241s
# [1340/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15451, val loss: 3.17737, in 0.162s
# [1341/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15448, val loss: 3.17736, in 0.187s
# [1342/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15443, val loss: 3.17734, in 0.205s
# [1343/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15441, val loss: 3.17733, in 0.171s
# [1344/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15438, val loss: 3.17733, in 0.171s
# [1345/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15436, val loss: 3.17733, in 0.194s
# [1346/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15435, val loss: 3.17732, in 0.158s
# [1347/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15435, val loss: 3.17732, in 0.147s
# [1348/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15434, val loss: 3.17732, in 0.169s
# [1349/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15434, val loss: 3.17733, in 0.171s
# [1350/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15433, val loss: 3.17733, in 0.147s
# [1351/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15433, val loss: 3.17733, in 0.232s
# [1352/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15432, val loss: 3.17733, in 0.156s
# [1353/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15432, val loss: 3.17733, in 0.187s
# [1354/100000] 1 tree, 31 leaves, max depth = 7, train loss: 3.15431, val loss: 3.17733, in 0.172s
# Fit 1354 trees in 359.530 s, (41974 total leaves)
# Time spent computing histograms: 52.566s
# Time spent finding best splits:  5.212s
# Time spent applying splits:      62.841s
# Time spent predicting:           15.096s
# MAE: 3.1765484371991346
#         y_true    y_pred     error
# 0         6.65  6.120257  0.529743
# 1        -4.17 -3.416258  0.753742
# 2        -6.46 -0.624250  5.835750
# 3         0.87  2.503628  1.633628
# 4         6.75  5.880632  0.869368
# ...        ...       ...       ...
# 827267    5.92  3.835198  2.084802
# 827268   -2.82 -1.521448  1.298552
# 827269   -8.30 -5.241829  3.058171
# 827270   -1.55 -2.634370  1.084370
# 827271   -6.12 -0.439789  5.680211
#
# [827272 rows x 3 columns]

# %% [markdown]
# # Recommendations to the users

# %% [markdown]
# ### Unseen jokes per user

# %%
def unseen_jokes_predict_ratings(user_id, estimator, user_joke_idxs, topics, n_recommendations=10):
    full_combinations = user_joke_idxs.loc[:, ['user_id']].drop_duplicates() \
                                    .merge(pd.DataFrame({'joke_id': np.arange(1, 101)}), how='cross')
    
    unseen_jokes_idxs = full_combinations.merge(user_joke_idxs, how='outer', indicator=True)
    unseen_jokes_idxs = unseen_jokes_idxs[~(unseen_jokes_idxs._merge == 'both')].drop('_merge', axis=1)
    unseen_jokes_user_id = unseen_jokes_idxs[unseen_jokes_idxs.user_id == user_id]

    user_id_laugh_dist_per_topic = \
        np.unique(X[user_joke_idxs[user_joke_idxs.user_id == user_id].index][:, X.shape[1] // 2:], axis=0) 
    user_id_laugh_dist_per_topic = pd.DataFrame(user_id_laugh_dist_per_topic).reset_index()
    user_id_laugh_dist_per_topic.rename(columns={'index': 'user_id'}, inplace=True)

    unseen_jokes_user_id = unseen_jokes_user_id.merge(topics, how='left', on='joke_id')
    unseen_jokes_user_id.rename(columns=dict(zip(list(range(len(topics.columns[1:]))),
                                            [f'jt_{c}' for c in topics.columns[1:]])),
                                            inplace=True)
    
    unseen_jokes_user_id = unseen_jokes_user_id[unseen_jokes_user_id.user_id == user_id] \
                            .merge(user_id_laugh_dist_per_topic, how='left', on='user_id')
    unseen_jokes_user_id.rename(columns=dict(zip(list(range(len(topics.columns[1:]))),
                                            [f'ujr_{c}' for c in topics.columns[1:]])),
                                            inplace=True)

    unseen_jokes_rating_pred = \
        pd.concat([unseen_jokes_user_id.loc[:, ['user_id', 'joke_id']], 
                   pd.DataFrame({'rating_pred': estimator.predict(unseen_jokes_user_id.iloc[:, 2:].values)})],
                  axis=1)
    unseen_jokes_rating_pred.sort_values(by='rating_pred', ascending=False, inplace=True)

    return unseen_jokes_rating_pred.iloc[:10, :]

# %%
users_list = list(range(5))
unseen_jokes_predictions = pd.concat([unseen_jokes_predict_ratings(user_id=user_id, 
                                                 estimator=hgb,
                                                 user_joke_idxs=user_joke_idxs, 
                                                 topics=topics)\
                                      for user_id in tqdm.tqdm(users_list)],
                                     axis=0)

display(unseen_jokes_predictions)
# Out:
# 100%|██████████| 5/5 [00:33<00:00,  6.71s/it]
#     user_id joke_id  rating_pred
# 64        0      91     3.495888
# 29        0      49     2.978571
# 62        0      89     2.763768
# 7         0      11     2.378543
# 27        0      46     2.204704
# 61        0      88     2.144989
# 59        0      86     1.920819
# 10        0      21     1.610546
# 32        0      54     1.446182
# 0         0       1     1.420417
# 56        1      89     2.003082
# 39        1      72     0.881198
# 33        1      61     0.716280
# 43        1      76     0.576938
# 48        1      81     0.554020
# 55        1      88     0.447226
# 50        1      83     0.275483
# 62        1      96     0.221627
# 58        1      91     0.156279
# 9         1      14     0.131924
# 38        2      50     2.220144
# 16        2      27     2.058099
# 72        2      89     2.003082
# 49        2      62     1.757786
# 42        2      54     1.723494
# 21        2      32     1.682873
# 51        2      65     1.378169
# 18        2      29     1.287942
# 54        2      68     1.260602
# 41        2      53     1.256957
# 66        3      89     2.003082
# 35        3      54     1.723494
# 44        3      65     1.378169
# 47        3      69     0.907661
# 50        3      72     0.881198
# 45        3      66     0.814196
# 32        3      49     0.747003
# 41        3      61     0.716280
# 25        3      42     0.641434
# 54        3      76     0.576938
# 66        4      89     2.003082
# 40        4      62     1.757786
# 33        4      54     1.723494
# 43        4      65     1.378169
# 46        4      68     1.260602
# 32        4      53     1.256957
# 47        4      69     0.907661
# 49        4      72     0.881198
# 44        4      66     0.814196
# 29        4      49     0.747003
